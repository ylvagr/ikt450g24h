# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import torch
from torch.utils.data import DataLoader, Subset
import torchvision.transforms as transforms
import torchxrayvision as xrv
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.metrics import classification_report, roc_auc_score, auc


def load_image_list(file_path):
    with open(file_path, 'r') as f:
        return set(line.strip() for line in f)


train_val_image_set = load_image_list('train_val_list.txt')
test_image_set = load_image_list('test_list.txt')


dataset = xrv.datasets.NIH_Dataset(
    imgpath='images/', 
    csvpath='dataset/Data_Entry_2017.csv',
    unique_patients=False,
    views=['PA', 'AP'],
)

transform = transforms.Compose([
    xrv.datasets.XRayCenterCrop(),
    xrv.datasets.XRayResizer(224)
])
dataset.transform = transform
# Out:
# /home/ylvag/.local/lib/python3.10/site-packages/torchxrayvision/utils.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
def filter_dataset_by_image_list(dataset, image_set):
    filtered_idxs = [i for i in range(len(dataset)) if os.path.basename(dataset.csv.iloc[i]["Image Index"]) in image_set]
    return xrv.datasets.SubsetDataset(dataset, filtered_idxs)


train_val_dataset = filter_dataset_by_image_list(dataset, train_val_image_set)
test_dataset = filter_dataset_by_image_list(dataset, test_image_set)


print(f"Training/Validation dataset size: {len(train_val_dataset)}")

df_train = train_val_dataset.csv 
patients = df_train['Patient ID'].unique() 

train_patients, val_patients = train_test_split(
    patients, test_size=0.15, random_state=42
)

train_indices = [
    idx for idx in range(len(train_val_dataset))
    if df_train.iloc[idx]['Patient ID'] in train_patients
]
val_indices = [
    idx for idx in range(len(train_val_dataset))
    if df_train.iloc[idx]['Patient ID'] in val_patients
]

train_dataset = Subset(train_val_dataset, train_indices)
val_dataset = Subset(train_val_dataset, val_indices)

print(f"Training dataset size: {len(train_dataset)}")
print(f"Validation dataset size: {len(val_dataset)}")
print(f"Testing dataset size: {len(test_dataset)}")
# Out:
# Training/Validation dataset size: 86524
# Training dataset size: 73916
# Validation dataset size: 12608
# Testing dataset size: 25596

# %%
batch_size = 32
num_workers = 64
pin_memory = True

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=pin_memory)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=pin_memory)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=pin_memory)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = xrv.models.DenseNet(weights="densenet121-res224-all")
model.op_threshs = None 
model.classifier = torch.nn.Linear(model.classifier.in_features, 14) 
model = model.to(device)

optimizer = torch.optim.Adam(model.classifier.parameters(), lr=0.0001)
criterion = torch.nn.BCEWithLogitsLoss()

# %%
thresholds = torch.tensor(
    [0.039117552, 0.0034529066, 0.11396341, 0.0057298196, 0.00045666535, 0.0018880932,
     0.012037827, 0.038744126, 0.0037213727, 0.014730946, 0.016149804, 0.054241467,
     0.037198864, 0.0004403434], 
    device=device
)

# The class names needs to correspond to the thresholds defined
class_names = ['Atelectasis', 'Consolidation', 'Infiltration', 'Pneumothorax', 'Edema', 'Emphysema', 'Fibrosis', 'Effusion', 'Pneumonia', 'Pleural_Thickening', 'Cardiomegaly', 'Nodule', 'Mass', 'Hernia']

# %%
# Messy code inc
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []
train_precisions = []
train_recalls = []
train_f1s = []
val_precisions = []
val_recalls = []
val_f1s = []
auc_scores = []

train_class_accuracies = [[] for _ in range(len(class_names))]
val_class_accuracies = [[] for _ in range(len(class_names))]

num_epochs = 30

# Training loop
for epoch in range(num_epochs):
    model.train()
    train_loss = 0
    correct = 0
    total = 0
    all_preds = []
    all_labels = []
    train_correct_per_class = [0] * len(class_names)
    train_total_per_class = [0] * len(class_names)

    for batch in train_loader:
        images = batch["img"].to(device)
        labels = batch["lab"].to(device)

        optimizer.zero_grad()
        outputs = model(images)
        probabilities = torch.sigmoid(outputs)
        loss = criterion(outputs, labels.float())
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        preds = (probabilities > thresholds).float() 
        correct += (preds == labels).sum().item()
        total += labels.numel()

        all_preds.append(preds.cpu())
        all_labels.append(labels.cpu())

        for i in range(len(class_names)):
            train_correct_per_class[i] += ((preds[:, i] == labels[:, i]) & (labels[:, i] == 1)).sum().item()
            train_total_per_class[i] += (labels[:, i] == 1).sum().item()

    all_preds = torch.cat(all_preds).numpy()
    all_labels = torch.cat(all_labels).numpy()

    train_losses.append(train_loss / len(train_loader))
    train_accuracies.append(correct / total)

    train_epoch_class_accuracies = [
        correct / total if total > 0 else 0
        for correct, total in zip(train_correct_per_class, train_total_per_class)
    ]
    for i in range(len(class_names)):
        train_class_accuracies[i].append(train_epoch_class_accuracies[i])

    # Validate on the validation dataset
    model.eval()
    val_loss = 0
    correct = 0
    total = 0
    all_preds = []
    all_preds_val = []
    all_labels = []
    val_correct_per_class = [0] * len(class_names)
    val_total_per_class = [0] * len(class_names)

    with torch.no_grad():
        for batch in val_loader:
            images = batch["img"].to(device)
            labels = batch["lab"].to(device)
            outputs = model(images)
            probabilities = torch.sigmoid(outputs)
            loss = criterion(outputs, labels.float())
            val_loss += loss.item()

            preds = (probabilities > thresholds).float()
            correct += (preds == labels).sum().item()
            total += labels.numel()

            all_preds.append(preds.cpu())
            all_preds_val.append(probabilities.cpu())
            all_labels.append(labels.cpu())

            for i in range(len(class_names)):
                val_correct_per_class[i] += ((preds[:, i] == labels[:, i]) & (labels[:, i] == 1)).sum().item()
                val_total_per_class[i] += (labels[:, i] == 1).sum().item()

    all_preds = torch.cat(all_preds).numpy()
    all_preds_val = torch.cat(all_preds_val).numpy()
    all_labels = torch.cat(all_labels).numpy()

    for i, class_name in enumerate(class_names):
        auc_score = roc_auc_score(all_labels[:, i], all_preds_val[:, i])
        auc_scores.append(auc)
        print(f"{class_name} - AUC: {auc_score:.4f}")

    class_report = classification_report(
        all_labels, all_preds, target_names=class_names, zero_division=0)
    print("Validation Classification Report:\n", class_report)

    val_losses.append(val_loss / len(val_loader))
    val_accuracies.append(correct / total)

    val_epoch_class_accuracies = [
        correct / total if total > 0 else 0
        for correct, total in zip(val_correct_per_class, val_total_per_class)
    ]
    for i in range(len(class_names)):
        val_class_accuracies[i].append(val_epoch_class_accuracies[i])

    print(f"Epoch {epoch+1}/{num_epochs} - "
          f"Train Loss: {train_losses[-1]:.4f}, Train Accuracy: {train_accuracies[-1]:.4f}, "
          f"Val Loss: {val_losses[-1]:.4f}, Val Accuracy: {val_accuracies[-1]:.4f}, ")

    print("\nTrain Per-Class Accuracy:")
    for i, class_name in enumerate(class_names):
        print(f"  {class_name}: {train_class_accuracies[i][-1]:.4f}")
    
    print("\nValidation Per-Class Accuracy:")
    for i, class_name in enumerate(class_names):
        print(f"  {class_name}: {val_class_accuracies[i][-1]:.4f}")
# Out:
# Atelectasis - AUC: 0.7397
# Consolidation - AUC: 0.6316
# Infiltration - AUC: 0.7653
# Pneumothorax - AUC: 0.7829
# Edema - AUC: 0.8605
# Emphysema - AUC: 0.7260
# Fibrosis - AUC: 0.5984
# Effusion - AUC: 0.5258
# Pneumonia - AUC: 0.6613
# Pleural_Thickening - AUC: 0.7486
# Cardiomegaly - AUC: 0.6274
# Nodule - AUC: 0.6796
# Mass - AUC: 0.6459
# Hernia - AUC: 0.7545
# Validation Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.12      0.97      0.22      1277
#      Consolidation       0.02      1.00      0.04       254
#       Infiltration       0.13      0.03      0.05       370
#       Pneumothorax       0.02      1.00      0.03       177
#              Edema       0.10      1.00      0.18      1244
#          Emphysema       0.01      1.00      0.02       149
#           Fibrosis       0.02      0.85      0.04       200
#           Effusion       0.00      0.04      0.00        28
#          Pneumonia       0.15      1.00      0.27      1929
# Pleural_Thickening       0.05      0.98      0.10       582
#       Cardiomegaly       0.05      0.99      0.10       666
#             Nodule       0.06      0.28      0.10       372
#               Mass       0.02      0.28      0.03       134
#             Hernia       0.03      1.00      0.05       350
#
#          micro avg       0.06      0.89      0.11      7732
#          macro avg       0.06      0.74      0.09      7732
#       weighted avg       0.10      0.89      0.16      7732
#        samples avg       0.05      0.37      0.09      7732
#
# Epoch 1/30 - Train Loss: 0.2149, Train Accuracy: 0.1896, Val Loss: 0.1493, Val Accuracy: 0.3473,
#
# Train Per-Class Accuracy:
#   Atelectasis: 0.9907
#   Consolidation: 1.0000
#   Infiltration: 0.4408
#   Pneumothorax: 1.0000
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.9715
#   Effusion: 0.6106
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9939
#   Cardiomegaly: 0.9975
#   Nodule: 0.7508
#   Mass: 0.7695
#   Hernia: 1.0000
#
# Validation Per-Class Accuracy:
#   Atelectasis: 0.9663
#   Consolidation: 1.0000
#   Infiltration: 0.0324
#   Pneumothorax: 1.0000
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.8550
#   Effusion: 0.0357
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9845
#   Cardiomegaly: 0.9865
#   Nodule: 0.2823
#   Mass: 0.2761
#   Hernia: 1.0000
#
# --------------------------------------------------
#
# Atelectasis - AUC: 0.7604
# Consolidation - AUC: 0.7830
# Infiltration - AUC: 0.7886
# Pneumothorax - AUC: 0.8530
# Edema - AUC: 0.8692
# Emphysema - AUC: 0.7336
# Fibrosis - AUC: 0.6489
# Effusion - AUC: 0.5809
# Pneumonia - AUC: 0.6718
# Pleural_Thickening - AUC: 0.8021
# Cardiomegaly - AUC: 0.6767
# Nodule - AUC: 0.7154
# Mass - AUC: 0.6616
# Hernia - AUC: 0.7751
# Validation Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.13      0.95      0.23      1277
#      Consolidation       0.02      1.00      0.04       254
#       Infiltration       0.12      0.09      0.10       370
#       Pneumothorax       0.02      0.99      0.05       177
#              Edema       0.10      1.00      0.18      1244
#          Emphysema       0.01      1.00      0.02       149
#           Fibrosis       0.02      0.73      0.04       200
#           Effusion       0.00      0.00      0.00        28
#          Pneumonia       0.15      1.00      0.27      1929
# Pleural_Thickening       0.06      0.97      0.11       582
#       Cardiomegaly       0.05      0.99      0.10       666
#             Nodule       0.08      0.22      0.12       372
#               Mass       0.02      0.03      0.02       134
#             Hernia       0.03      1.00      0.05       350
#
#          micro avg       0.06      0.88      0.12      7732
#          macro avg       0.06      0.71      0.10      7732
#       weighted avg       0.10      0.88      0.17      7732
#        samples avg       0.06      0.36      0.10      7732
#
# Epoch 2/30 - Train Loss: 0.1485, Train Accuracy: 0.3895, Val Loss: 0.1426, Val Accuracy: 0.4147,
#
# Train Per-Class Accuracy:
#   Atelectasis: 0.9629
#   Consolidation: 1.0000
#   Infiltration: 0.0556
#   Pneumothorax: 0.9867
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.7735
#   Effusion: 0.0088
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9681
#   Cardiomegaly: 0.9916
#   Nodule: 0.2824
#   Mass: 0.1253
#   Hernia: 1.0000
#
# Validation Per-Class Accuracy:
#   Atelectasis: 0.9499
#   Consolidation: 1.0000
#   Infiltration: 0.0865
#   Pneumothorax: 0.9887
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.7350
#   Effusion: 0.0000
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9708
#   Cardiomegaly: 0.9865
#   Nodule: 0.2231
#   Mass: 0.0299
#   Hernia: 1.0000
#
# --------------------------------------------------
#
# Atelectasis - AUC: 0.7686
# Consolidation - AUC: 0.8619
# Infiltration - AUC: 0.7973
# Pneumothorax - AUC: 0.8784
# Edema - AUC: 0.8723
# Emphysema - AUC: 0.7418
# Fibrosis - AUC: 0.6960
# Effusion - AUC: 0.6801
# Pneumonia - AUC: 0.6748
# Pleural_Thickening - AUC: 0.8187
# Cardiomegaly - AUC: 0.6957
# Nodule - AUC: 0.7389
# Mass - AUC: 0.6773
# Hernia - AUC: 0.7878
# Validation Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.14      0.94      0.24      1277
#      Consolidation       0.02      1.00      0.04       254
#       Infiltration       0.12      0.17      0.14       370
#       Pneumothorax       0.03      0.98      0.05       177
#              Edema       0.10      1.00      0.18      1244
#          Emphysema       0.01      1.00      0.02       149
#           Fibrosis       0.02      0.76      0.05       200
#           Effusion       0.00      0.00      0.00        28
#          Pneumonia       0.15      1.00      0.27      1929
# Pleural_Thickening       0.07      0.95      0.12       582
#       Cardiomegaly       0.05      0.99      0.10       666
#             Nodule       0.09      0.26      0.14       372
#               Mass       0.04      0.04      0.04       134
#             Hernia       0.03      1.00      0.05       350
#
#          micro avg       0.07      0.88      0.12      7732
#          macro avg       0.06      0.72      0.10      7732
#       weighted avg       0.10      0.88      0.17      7732
#        samples avg       0.06      0.37      0.10      7732
#
# Epoch 3/30 - Train Loss: 0.1444, Train Accuracy: 0.4227, Val Loss: 0.1399, Val Accuracy: 0.4405,
#
# Train Per-Class Accuracy:
#   Atelectasis: 0.9483
#   Consolidation: 1.0000
#   Infiltration: 0.1442
#   Pneumothorax: 0.9634
#   Edema: 1.0000
#   Emphysema: 0.9984
#   Fibrosis: 0.7612
#   Effusion: 0.0000
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9606
#   Cardiomegaly: 0.9889
#   Nodule: 0.3251
#   Mass: 0.0310
#   Hernia: 1.0000
#
# Validation Per-Class Accuracy:
#   Atelectasis: 0.9389
#   Consolidation: 1.0000
#   Infiltration: 0.1703
#   Pneumothorax: 0.9831
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.7600
#   Effusion: 0.0000
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9485
#   Cardiomegaly: 0.9895
#   Nodule: 0.2608
#   Mass: 0.0373
#   Hernia: 1.0000
#
# --------------------------------------------------
#
# Atelectasis - AUC: 0.7725
# Consolidation - AUC: 0.8808
# Infiltration - AUC: 0.8014
# Pneumothorax - AUC: 0.8872
# Edema - AUC: 0.8744
# Emphysema - AUC: 0.7505
# Fibrosis - AUC: 0.7193
# Effusion - AUC: 0.7684
# Pneumonia - AUC: 0.6765
# Pleural_Thickening - AUC: 0.8234
# Cardiomegaly - AUC: 0.7018
# Nodule - AUC: 0.7484
# Mass - AUC: 0.6901
# Hernia - AUC: 0.7940
# Validation Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.14      0.94      0.25      1277
#      Consolidation       0.02      1.00      0.04       254
#       Infiltration       0.12      0.24      0.16       370
#       Pneumothorax       0.03      0.98      0.06       177
#              Edema       0.10      1.00      0.18      1244
#          Emphysema       0.01      1.00      0.02       149
#           Fibrosis       0.03      0.77      0.05       200
#           Effusion       0.00      0.00      0.00        28
#          Pneumonia       0.15      1.00      0.27      1929
# Pleural_Thickening       0.06      0.96      0.12       582
#       Cardiomegaly       0.06      0.98      0.10       666
#             Nodule       0.10      0.31      0.15       372
#               Mass       0.02      0.01      0.02       134
#             Hernia       0.03      1.00      0.05       350
#
#          micro avg       0.07      0.89      0.12      7732
#          macro avg       0.06      0.73      0.10      7732
#       weighted avg       0.10      0.89      0.18      7732
#        samples avg       0.06      0.37      0.10      7732
#
# Epoch 4/30 - Train Loss: 0.1424, Train Accuracy: 0.4385, Val Loss: 0.1386, Val Accuracy: 0.4445,
#
# Train Per-Class Accuracy:
#   Atelectasis: 0.9403
#   Consolidation: 0.9986
#   Infiltration: 0.2099
#   Pneumothorax: 0.9542
#   Edema: 1.0000
#   Emphysema: 0.9953
#   Fibrosis: 0.7783
#   Effusion: 0.0000
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9481
#   Cardiomegaly: 0.9886
#   Nodule: 0.3529
#   Mass: 0.0350
#   Hernia: 1.0000
#
# Validation Per-Class Accuracy:
#   Atelectasis: 0.9374
#   Consolidation: 1.0000
#   Infiltration: 0.2351
#   Pneumothorax: 0.9831
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.7700
#   Effusion: 0.0000
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9553
#   Cardiomegaly: 0.9850
#   Nodule: 0.3091
#   Mass: 0.0149
#   Hernia: 1.0000
#
# --------------------------------------------------
#
# Atelectasis - AUC: 0.7741
# Consolidation - AUC: 0.8843
# Infiltration - AUC: 0.8042
# Pneumothorax - AUC: 0.8923
# Edema - AUC: 0.8761
# Emphysema - AUC: 0.7582
# Fibrosis - AUC: 0.7295
# Effusion - AUC: 0.8157
# Pneumonia - AUC: 0.6781
# Pleural_Thickening - AUC: 0.8260
# Cardiomegaly - AUC: 0.7059
# Nodule - AUC: 0.7533
# Mass - AUC: 0.6988
# Hernia - AUC: 0.7992
# Validation Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.14      0.93      0.25      1277
#      Consolidation       0.02      1.00      0.05       254
#       Infiltration       0.12      0.25      0.17       370
#       Pneumothorax       0.03      0.98      0.06       177
#              Edema       0.10      1.00      0.18      1244
#          Emphysema       0.01      1.00      0.03       149
#           Fibrosis       0.03      0.80      0.05       200
#           Effusion       0.00      0.00      0.00        28
#          Pneumonia       0.15      1.00      0.27      1929
# Pleural_Thickening       0.07      0.95      0.12       582
#       Cardiomegaly       0.06      0.98      0.10       666
#             Nodule       0.10      0.36      0.16       372
#               Mass       0.03      0.01      0.02       134
#             Hernia       0.03      1.00      0.05       350
#
#          micro avg       0.07      0.89      0.13      7732
#          macro avg       0.06      0.73      0.11      7732
#       weighted avg       0.10      0.89      0.18      7732
#        samples avg       0.06      0.37      0.10      7732
#
# Epoch 5/30 - Train Loss: 0.1413, Train Accuracy: 0.4483, Val Loss: 0.1379, Val Accuracy: 0.4548,
#
# Train Per-Class Accuracy:
#   Atelectasis: 0.9365
#   Consolidation: 0.9959
#   Infiltration: 0.2470
#   Pneumothorax: 0.9609
#   Edema: 1.0000
#   Emphysema: 0.9969
#   Fibrosis: 0.7821
#   Effusion: 0.0000
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9444
#   Cardiomegaly: 0.9874
#   Nodule: 0.3770
#   Mass: 0.0445
#   Hernia: 1.0000
#
# Validation Per-Class Accuracy:
#   Atelectasis: 0.9280
#   Consolidation: 1.0000
#   Infiltration: 0.2541
#   Pneumothorax: 0.9831
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.7950
#   Effusion: 0.0000
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9485
#   Cardiomegaly: 0.9835
#   Nodule: 0.3602
#   Mass: 0.0149
#   Hernia: 1.0000
#
# --------------------------------------------------
#
# Atelectasis - AUC: 0.7747
# Consolidation - AUC: 0.8897
# Infiltration - AUC: 0.8058
# Pneumothorax - AUC: 0.8935
# Edema - AUC: 0.8769
# Emphysema - AUC: 0.7587
# Fibrosis - AUC: 0.7356
# Effusion - AUC: 0.8537
# Pneumonia - AUC: 0.6788
# Pleural_Thickening - AUC: 0.8272
# Cardiomegaly - AUC: 0.7073
# Nodule - AUC: 0.7602
# Mass - AUC: 0.7095
# Hernia - AUC: 0.8006
# Validation Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.15      0.92      0.25      1277
#      Consolidation       0.03      0.99      0.05       254
#       Infiltration       0.12      0.23      0.16       370
#       Pneumothorax       0.03      0.97      0.06       177
#              Edema       0.10      1.00      0.18      1244
#          Emphysema       0.01      1.00      0.03       149
#           Fibrosis       0.03      0.79      0.05       200
#           Effusion       0.00      0.00      0.00        28
#          Pneumonia       0.15      1.00      0.27      1929
# Pleural_Thickening       0.07      0.93      0.13       582
#       Cardiomegaly       0.06      0.98      0.11       666
#             Nodule       0.10      0.40      0.16       372
#               Mass       0.04      0.05      0.04       134
#             Hernia       0.03      1.00      0.05       350
#
#          micro avg       0.07      0.89      0.13      7732
#          macro avg       0.06      0.73      0.11      7732
#       weighted avg       0.10      0.89      0.18      7732
#        samples avg       0.06      0.37      0.10      7732
#
# Epoch 6/30 - Train Loss: 0.1406, Train Accuracy: 0.4578, Val Loss: 0.1373, Val Accuracy: 0.4678,
#
# Train Per-Class Accuracy:
#   Atelectasis: 0.9312
#   Consolidation: 0.9966
#   Infiltration: 0.2587
#   Pneumothorax: 0.9450
#   Edema: 1.0000
#   Emphysema: 0.9945
#   Fibrosis: 0.7831
#   Effusion: 0.0000
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9383
#   Cardiomegaly: 0.9864
#   Nodule: 0.3818
#   Mass: 0.0418
#   Hernia: 1.0000
#
# Validation Per-Class Accuracy:
#   Atelectasis: 0.9217
#   Consolidation: 0.9882
#   Infiltration: 0.2297
#   Pneumothorax: 0.9661
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.7900
#   Effusion: 0.0000
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9296
#   Cardiomegaly: 0.9835
#   Nodule: 0.4032
#   Mass: 0.0522
#   Hernia: 1.0000
#
# --------------------------------------------------
#
# Atelectasis - AUC: 0.7756
# Consolidation - AUC: 0.8897
# Infiltration - AUC: 0.8079
# Pneumothorax - AUC: 0.8959
# Edema - AUC: 0.8775
# Emphysema - AUC: 0.7634
# Fibrosis - AUC: 0.7420
# Effusion - AUC: 0.8639
# Pneumonia - AUC: 0.6793
# Pleural_Thickening - AUC: 0.8269
# Cardiomegaly - AUC: 0.7123
# Nodule - AUC: 0.7609
# Mass - AUC: 0.7164
# Hernia - AUC: 0.8029
# Validation Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.15      0.93      0.25      1277
#      Consolidation       0.03      0.99      0.06       254
#       Infiltration       0.13      0.28      0.18       370
#       Pneumothorax       0.03      0.98      0.06       177
#              Edema       0.10      1.00      0.18      1244
#          Emphysema       0.01      1.00      0.03       149
#           Fibrosis       0.03      0.77      0.06       200
#           Effusion       0.71      0.18      0.29        28
#          Pneumonia       0.15      1.00      0.27      1929
# Pleural_Thickening       0.07      0.94      0.12       582
#       Cardiomegaly       0.05      0.99      0.10       666
#             Nodule       0.10      0.38      0.16       372
#               Mass       0.02      0.03      0.02       134
#             Hernia       0.03      1.00      0.05       350
#
#          micro avg       0.07      0.89      0.13      7732
#          macro avg       0.12      0.75      0.13      7732
#       weighted avg       0.11      0.89      0.18      7732
#        samples avg       0.06      0.37      0.10      7732
#
# Epoch 7/30 - Train Loss: 0.1401, Train Accuracy: 0.4641, Val Loss: 0.1370, Val Accuracy: 0.4708,
#
# Train Per-Class Accuracy:
#   Atelectasis: 0.9325
#   Consolidation: 0.9938
#   Infiltration: 0.2583
#   Pneumothorax: 0.9517
#   Edema: 1.0000
#   Emphysema: 0.9969
#   Fibrosis: 0.7897
#   Effusion: 0.0442
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9340
#   Cardiomegaly: 0.9847
#   Nodule: 0.4032
#   Mass: 0.0566
#   Hernia: 1.0000
#
# Validation Per-Class Accuracy:
#   Atelectasis: 0.9256
#   Consolidation: 0.9882
#   Infiltration: 0.2811
#   Pneumothorax: 0.9831
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.7700
#   Effusion: 0.1786
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9364
#   Cardiomegaly: 0.9865
#   Nodule: 0.3844
#   Mass: 0.0299
#   Hernia: 1.0000
#
# --------------------------------------------------
#
# Atelectasis - AUC: 0.7764
# Consolidation - AUC: 0.8914
# Infiltration - AUC: 0.8084
# Pneumothorax - AUC: 0.8967
# Edema - AUC: 0.8781
# Emphysema - AUC: 0.7627
# Fibrosis - AUC: 0.7445
# Effusion - AUC: 0.8735
# Pneumonia - AUC: 0.6799
# Pleural_Thickening - AUC: 0.8274
# Cardiomegaly - AUC: 0.7124
# Nodule - AUC: 0.7635
# Mass - AUC: 0.7203
# Hernia - AUC: 0.8042
# Validation Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.15      0.92      0.25      1277
#      Consolidation       0.03      0.99      0.06       254
#       Infiltration       0.13      0.25      0.17       370
#       Pneumothorax       0.03      0.97      0.06       177
#              Edema       0.10      1.00      0.18      1244
#          Emphysema       0.01      1.00      0.03       149
#           Fibrosis       0.03      0.78      0.06       200
#           Effusion       0.42      0.18      0.25        28
#          Pneumonia       0.15      1.00      0.27      1929
# Pleural_Thickening       0.07      0.93      0.13       582
#       Cardiomegaly       0.06      0.98      0.11       666
#             Nodule       0.11      0.38      0.17       372
#               Mass       0.02      0.02      0.02       134
#             Hernia       0.03      1.00      0.05       350
#
#          micro avg       0.07      0.89      0.13      7732
#          macro avg       0.10      0.74      0.13      7732
#       weighted avg       0.11      0.89      0.18      7732
#        samples avg       0.06      0.37      0.11      7732
#
# Epoch 8/30 - Train Loss: 0.1398, Train Accuracy: 0.4697, Val Loss: 0.1367, Val Accuracy: 0.4834,
#
# Train Per-Class Accuracy:
#   Atelectasis: 0.9322
#   Consolidation: 0.9897
#   Infiltration: 0.2619
#   Pneumothorax: 0.9525
#   Edema: 1.0000
#   Emphysema: 0.9976
#   Fibrosis: 0.7888
#   Effusion: 0.1947
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9389
#   Cardiomegaly: 0.9864
#   Nodule: 0.4176
#   Mass: 0.0701
#   Hernia: 1.0000
#
# Validation Per-Class Accuracy:
#   Atelectasis: 0.9217
#   Consolidation: 0.9882
#   Infiltration: 0.2514
#   Pneumothorax: 0.9661
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.7750
#   Effusion: 0.1786
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9278
#   Cardiomegaly: 0.9760
#   Nodule: 0.3763
#   Mass: 0.0224
#   Hernia: 1.0000
#
# --------------------------------------------------
#
# Atelectasis - AUC: 0.7765
# Consolidation - AUC: 0.8921
# Infiltration - AUC: 0.8091
# Pneumothorax - AUC: 0.8977
# Edema - AUC: 0.8791
# Emphysema - AUC: 0.7675
# Fibrosis - AUC: 0.7486
# Effusion - AUC: 0.8711
# Pneumonia - AUC: 0.6810
# Pleural_Thickening - AUC: 0.8277
# Cardiomegaly - AUC: 0.7112
# Nodule - AUC: 0.7632
# Mass - AUC: 0.7226
# Hernia - AUC: 0.8061
# Validation Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.15      0.91      0.26      1277
#      Consolidation       0.03      0.98      0.06       254
#       Infiltration       0.13      0.24      0.17       370
#       Pneumothorax       0.03      0.97      0.06       177
#              Edema       0.10      1.00      0.18      1244
#          Emphysema       0.01      1.00      0.03       149
#           Fibrosis       0.03      0.79      0.06       200
#           Effusion       0.46      0.21      0.29        28
#          Pneumonia       0.15      1.00      0.27      1929
# Pleural_Thickening       0.07      0.93      0.13       582
#       Cardiomegaly       0.06      0.98      0.11       666
#             Nodule       0.12      0.41      0.18       372
#               Mass       0.04      0.06      0.05       134
#             Hernia       0.03      1.00      0.05       350
#
#          micro avg       0.07      0.89      0.13      7732
#          macro avg       0.10      0.75      0.13      7732
#       weighted avg       0.11      0.89      0.18      7732
#        samples avg       0.06      0.37      0.11      7732
#
# Epoch 9/30 - Train Loss: 0.1395, Train Accuracy: 0.4727, Val Loss: 0.1366, Val Accuracy: 0.4831,
#
# Train Per-Class Accuracy:
#   Atelectasis: 0.9312
#   Consolidation: 0.9911
#   Infiltration: 0.2639
#   Pneumothorax: 0.9500
#   Edema: 1.0000
#   Emphysema: 0.9945
#   Fibrosis: 0.7793
#   Effusion: 0.2920
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9340
#   Cardiomegaly: 0.9837
#   Nodule: 0.4134
#   Mass: 0.0916
#   Hernia: 1.0000
#
# Validation Per-Class Accuracy:
#   Atelectasis: 0.9115
#   Consolidation: 0.9843
#   Infiltration: 0.2378
#   Pneumothorax: 0.9718
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.7850
#   Effusion: 0.2143
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9261
#   Cardiomegaly: 0.9805
#   Nodule: 0.4113
#   Mass: 0.0597
#   Hernia: 1.0000
#
# --------------------------------------------------
#
# Atelectasis - AUC: 0.7770
# Consolidation - AUC: 0.8931
# Infiltration - AUC: 0.8102
# Pneumothorax - AUC: 0.8978
# Edema - AUC: 0.8793
# Emphysema - AUC: 0.7681
# Fibrosis - AUC: 0.7498
# Effusion - AUC: 0.8816
# Pneumonia - AUC: 0.6814
# Pleural_Thickening - AUC: 0.8277
# Cardiomegaly - AUC: 0.7137
# Nodule - AUC: 0.7662
# Mass - AUC: 0.7275
# Hernia - AUC: 0.8069
# Validation Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.15      0.91      0.26      1277
#      Consolidation       0.03      0.98      0.06       254
#       Infiltration       0.13      0.22      0.17       370
#       Pneumothorax       0.03      0.97      0.06       177
#              Edema       0.10      1.00      0.18      1244
#          Emphysema       0.01      1.00      0.03       149
#           Fibrosis       0.03      0.78      0.06       200
#           Effusion       0.48      0.39      0.43        28
#          Pneumonia       0.15      1.00      0.27      1929
# Pleural_Thickening       0.07      0.93      0.12       582
#       Cardiomegaly       0.06      0.98      0.10       666
#             Nodule       0.11      0.42      0.18       372
#               Mass       0.04      0.07      0.05       134
#             Hernia       0.03      1.00      0.05       350
#
#          micro avg       0.07      0.89      0.13      7732
#          macro avg       0.10      0.76      0.14      7732
#       weighted avg       0.11      0.89      0.18      7732
#        samples avg       0.06      0.37      0.11      7732
#
# Epoch 10/30 - Train Loss: 0.1393, Train Accuracy: 0.4748, Val Loss: 0.1364, Val Accuracy: 0.4817,
#
# Train Per-Class Accuracy:
#   Atelectasis: 0.9312
#   Consolidation: 0.9869
#   Infiltration: 0.2861
#   Pneumothorax: 0.9567
#   Edema: 1.0000
#   Emphysema: 0.9953
#   Fibrosis: 0.7850
#   Effusion: 0.3717
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9313
#   Cardiomegaly: 0.9854
#   Nodule: 0.4214
#   Mass: 0.0849
#   Hernia: 1.0000
#
# Validation Per-Class Accuracy:
#   Atelectasis: 0.9139
#   Consolidation: 0.9843
#   Infiltration: 0.2216
#   Pneumothorax: 0.9661
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.7800
#   Effusion: 0.3929
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9347
#   Cardiomegaly: 0.9835
#   Nodule: 0.4194
#   Mass: 0.0672
#   Hernia: 1.0000
#
# --------------------------------------------------
#
# Atelectasis - AUC: 0.7782
# Consolidation - AUC: 0.8927
# Infiltration - AUC: 0.8114
# Pneumothorax - AUC: 0.8985
# Edema - AUC: 0.8792
# Emphysema - AUC: 0.7700
# Fibrosis - AUC: 0.7528
# Effusion - AUC: 0.8783
# Pneumonia - AUC: 0.6817
# Pleural_Thickening - AUC: 0.8284
# Cardiomegaly - AUC: 0.7161
# Nodule - AUC: 0.7663
# Mass - AUC: 0.7282
# Hernia - AUC: 0.8081
# Validation Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.14      0.93      0.25      1277
#      Consolidation       0.03      0.98      0.06       254
#       Infiltration       0.14      0.32      0.19       370
#       Pneumothorax       0.03      0.97      0.06       177
#              Edema       0.10      1.00      0.18      1244
#          Emphysema       0.01      1.00      0.03       149
#           Fibrosis       0.03      0.74      0.06       200
#           Effusion       0.48      0.43      0.45        28
#          Pneumonia       0.15      1.00      0.27      1929
# Pleural_Thickening       0.07      0.93      0.12       582
#       Cardiomegaly       0.06      0.97      0.11       666
#             Nodule       0.11      0.39      0.18       372
#               Mass       0.03      0.06      0.04       134
#             Hernia       0.03      1.00      0.05       350
#
#          micro avg       0.07      0.89      0.13      7732
#          macro avg       0.10      0.77      0.15      7732
#       weighted avg       0.11      0.89      0.18      7732
#        samples avg       0.06      0.37      0.11      7732
#
# Epoch 11/30 - Train Loss: 0.1391, Train Accuracy: 0.4774, Val Loss: 0.1364, Val Accuracy: 0.4862,
#
# Train Per-Class Accuracy:
#   Atelectasis: 0.9283
#   Consolidation: 0.9869
#   Infiltration: 0.2716
#   Pneumothorax: 0.9517
#   Edema: 1.0000
#   Emphysema: 0.9937
#   Fibrosis: 0.7831
#   Effusion: 0.4425
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9345
#   Cardiomegaly: 0.9866
#   Nodule: 0.4305
#   Mass: 0.0930
#   Hernia: 1.0000
#
# Validation Per-Class Accuracy:
#   Atelectasis: 0.9342
#   Consolidation: 0.9843
#   Infiltration: 0.3216
#   Pneumothorax: 0.9718
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.7400
#   Effusion: 0.4286
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9330
#   Cardiomegaly: 0.9700
#   Nodule: 0.3898
#   Mass: 0.0597
#   Hernia: 1.0000
#
# --------------------------------------------------
#
# Atelectasis - AUC: 0.7785
# Consolidation - AUC: 0.8935
# Infiltration - AUC: 0.8116
# Pneumothorax - AUC: 0.8984
# Edema - AUC: 0.8797
# Emphysema - AUC: 0.7710
# Fibrosis - AUC: 0.7579
# Effusion - AUC: 0.8805
# Pneumonia - AUC: 0.6819
# Pleural_Thickening - AUC: 0.8284
# Cardiomegaly - AUC: 0.7155
# Nodule - AUC: 0.7675
# Mass - AUC: 0.7325
# Hernia - AUC: 0.8092
# Validation Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.15      0.92      0.26      1277
#      Consolidation       0.03      0.98      0.06       254
#       Infiltration       0.14      0.24      0.17       370
#       Pneumothorax       0.03      0.97      0.06       177
#              Edema       0.10      1.00      0.18      1244
#          Emphysema       0.01      1.00      0.03       149
#           Fibrosis       0.03      0.79      0.06       200
#           Effusion       0.46      0.43      0.44        28
#          Pneumonia       0.15      1.00      0.27      1929
# Pleural_Thickening       0.07      0.92      0.13       582
#       Cardiomegaly       0.06      0.98      0.11       666
#             Nodule       0.12      0.42      0.18       372
#               Mass       0.04      0.09      0.06       134
#             Hernia       0.03      1.00      0.05       350
#
#          micro avg       0.07      0.89      0.13      7732
#          macro avg       0.10      0.77      0.15      7732
#       weighted avg       0.11      0.89      0.18      7732
#        samples avg       0.06      0.37      0.11      7732
#
# Epoch 12/30 - Train Loss: 0.1388, Train Accuracy: 0.4801, Val Loss: 0.1361, Val Accuracy: 0.4908,
#
# Train Per-Class Accuracy:
#   Atelectasis: 0.9305
#   Consolidation: 0.9862
#   Infiltration: 0.2873
#   Pneumothorax: 0.9500
#   Edema: 1.0000
#   Emphysema: 0.9945
#   Fibrosis: 0.7821
#   Effusion: 0.4867
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9337
#   Cardiomegaly: 0.9854
#   Nodule: 0.4251
#   Mass: 0.0795
#   Hernia: 1.0000
#
# Validation Per-Class Accuracy:
#   Atelectasis: 0.9178
#   Consolidation: 0.9843
#   Infiltration: 0.2378
#   Pneumothorax: 0.9661
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.7850
#   Effusion: 0.4286
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9244
#   Cardiomegaly: 0.9790
#   Nodule: 0.4247
#   Mass: 0.0896
#   Hernia: 1.0000
#
# --------------------------------------------------
#
# Atelectasis - AUC: 0.7782
# Consolidation - AUC: 0.8950
# Infiltration - AUC: 0.8122
# Pneumothorax - AUC: 0.8980
# Edema - AUC: 0.8796
# Emphysema - AUC: 0.7697
# Fibrosis - AUC: 0.7561
# Effusion - AUC: 0.8855
# Pneumonia - AUC: 0.6823
# Pleural_Thickening - AUC: 0.8291
# Cardiomegaly - AUC: 0.7170
# Nodule - AUC: 0.7685
# Mass - AUC: 0.7338
# Hernia - AUC: 0.8090
# Validation Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.15      0.92      0.26      1277
#      Consolidation       0.03      0.98      0.06       254
#       Infiltration       0.14      0.29      0.19       370
#       Pneumothorax       0.03      0.96      0.06       177
#              Edema       0.10      1.00      0.18      1244
#          Emphysema       0.01      1.00      0.03       149
#           Fibrosis       0.03      0.74      0.06       200
#           Effusion       0.35      0.43      0.39        28
#          Pneumonia       0.15      1.00      0.27      1929
# Pleural_Thickening       0.07      0.93      0.13       582
#       Cardiomegaly       0.06      0.98      0.11       666
#             Nodule       0.11      0.44      0.18       372
#               Mass       0.05      0.09      0.06       134
#             Hernia       0.03      1.00      0.05       350
#
#          micro avg       0.07      0.89      0.13      7732
#          macro avg       0.09      0.77      0.14      7732
#       weighted avg       0.11      0.89      0.18      7732
#        samples avg       0.06      0.37      0.11      7732
#
# Epoch 13/30 - Train Loss: 0.1388, Train Accuracy: 0.4804, Val Loss: 0.1360, Val Accuracy: 0.4927,
#
# Train Per-Class Accuracy:
#   Atelectasis: 0.9307
#   Consolidation: 0.9849
#   Infiltration: 0.2889
#   Pneumothorax: 0.9525
#   Edema: 1.0000
#   Emphysema: 0.9922
#   Fibrosis: 0.7935
#   Effusion: 0.4956
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9368
#   Cardiomegaly: 0.9857
#   Nodule: 0.4230
#   Mass: 0.1065
#   Hernia: 1.0000
#
# Validation Per-Class Accuracy:
#   Atelectasis: 0.9193
#   Consolidation: 0.9843
#   Infiltration: 0.2865
#   Pneumothorax: 0.9605
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.7450
#   Effusion: 0.4286
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9261
#   Cardiomegaly: 0.9775
#   Nodule: 0.4409
#   Mass: 0.0896
#   Hernia: 1.0000
#
# --------------------------------------------------
#
# Atelectasis - AUC: 0.7790
# Consolidation - AUC: 0.8940
# Infiltration - AUC: 0.8125
# Pneumothorax - AUC: 0.8985
# Edema - AUC: 0.8799
# Emphysema - AUC: 0.7729
# Fibrosis - AUC: 0.7611
# Effusion - AUC: 0.8843
# Pneumonia - AUC: 0.6821
# Pleural_Thickening - AUC: 0.8284
# Cardiomegaly - AUC: 0.7182
# Nodule - AUC: 0.7694
# Mass - AUC: 0.7340
# Hernia - AUC: 0.8104
# Validation Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.15      0.93      0.25      1277
#      Consolidation       0.03      0.98      0.06       254
#       Infiltration       0.14      0.29      0.18       370
#       Pneumothorax       0.03      0.96      0.07       177
#              Edema       0.10      1.00      0.18      1244
#          Emphysema       0.01      1.00      0.03       149
#           Fibrosis       0.03      0.79      0.06       200
#           Effusion       0.32      0.46      0.38        28
#          Pneumonia       0.15      1.00      0.27      1929
# Pleural_Thickening       0.07      0.93      0.13       582
#       Cardiomegaly       0.06      0.98      0.11       666
#             Nodule       0.11      0.44      0.18       372
#               Mass       0.04      0.07      0.05       134
#             Hernia       0.03      1.00      0.05       350
#
#          micro avg       0.07      0.90      0.13      7732
#          macro avg       0.09      0.77      0.14      7732
#       weighted avg       0.11      0.90      0.18      7732
#        samples avg       0.06      0.37      0.11      7732
#
# Epoch 14/30 - Train Loss: 0.1387, Train Accuracy: 0.4827, Val Loss: 0.1359, Val Accuracy: 0.4853,
#
# Train Per-Class Accuracy:
#   Atelectasis: 0.9315
#   Consolidation: 0.9849
#   Infiltration: 0.2796
#   Pneumothorax: 0.9534
#   Edema: 1.0000
#   Emphysema: 0.9945
#   Fibrosis: 0.7850
#   Effusion: 0.5044
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9302
#   Cardiomegaly: 0.9861
#   Nodule: 0.4273
#   Mass: 0.1011
#   Hernia: 1.0000
#
# Validation Per-Class Accuracy:
#   Atelectasis: 0.9272
#   Consolidation: 0.9843
#   Infiltration: 0.2892
#   Pneumothorax: 0.9605
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.7850
#   Effusion: 0.4643
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9278
#   Cardiomegaly: 0.9835
#   Nodule: 0.4409
#   Mass: 0.0672
#   Hernia: 1.0000
#
# --------------------------------------------------
#
# Atelectasis - AUC: 0.7782
# Consolidation - AUC: 0.8956
# Infiltration - AUC: 0.8124
# Pneumothorax - AUC: 0.8987
# Edema - AUC: 0.8805
# Emphysema - AUC: 0.7738
# Fibrosis - AUC: 0.7591
# Effusion - AUC: 0.8893
# Pneumonia - AUC: 0.6834
# Pleural_Thickening - AUC: 0.8290
# Cardiomegaly - AUC: 0.7137
# Nodule - AUC: 0.7693
# Mass - AUC: 0.7332
# Hernia - AUC: 0.8107
# Validation Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.15      0.91      0.26      1277
#      Consolidation       0.03      0.98      0.06       254
#       Infiltration       0.14      0.25      0.17       370
#       Pneumothorax       0.03      0.95      0.07       177
#              Edema       0.10      1.00      0.18      1244
#          Emphysema       0.01      1.00      0.03       149
#           Fibrosis       0.03      0.80      0.06       200
#           Effusion       0.37      0.46      0.41        28
#          Pneumonia       0.15      1.00      0.27      1929
# Pleural_Thickening       0.07      0.93      0.13       582
#       Cardiomegaly       0.06      0.98      0.10       666
#             Nodule       0.11      0.46      0.18       372
#               Mass       0.04      0.10      0.06       134
#             Hernia       0.03      1.00      0.05       350
#
#          micro avg       0.07      0.89      0.13      7732
#          macro avg       0.09      0.77      0.14      7732
#       weighted avg       0.11      0.89      0.18      7732
#        samples avg       0.06      0.37      0.11      7732
#
# Epoch 15/30 - Train Loss: 0.1387, Train Accuracy: 0.4833, Val Loss: 0.1360, Val Accuracy: 0.4865,
#
# Train Per-Class Accuracy:
#   Atelectasis: 0.9299
#   Consolidation: 0.9869
#   Infiltration: 0.2998
#   Pneumothorax: 0.9475
#   Edema: 1.0000
#   Emphysema: 0.9945
#   Fibrosis: 0.7869
#   Effusion: 0.5044
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9340
#   Cardiomegaly: 0.9847
#   Nodule: 0.4251
#   Mass: 0.1092
#   Hernia: 1.0000
#
# Validation Per-Class Accuracy:
#   Atelectasis: 0.9139
#   Consolidation: 0.9843
#   Infiltration: 0.2459
#   Pneumothorax: 0.9548
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.8000
#   Effusion: 0.4643
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9278
#   Cardiomegaly: 0.9760
#   Nodule: 0.4570
#   Mass: 0.0970
#   Hernia: 1.0000
#
# --------------------------------------------------
#
# Atelectasis - AUC: 0.7787
# Consolidation - AUC: 0.8948
# Infiltration - AUC: 0.8127
# Pneumothorax - AUC: 0.8988
# Edema - AUC: 0.8804
# Emphysema - AUC: 0.7759
# Fibrosis - AUC: 0.7623
# Effusion - AUC: 0.8842
# Pneumonia - AUC: 0.6833
# Pleural_Thickening - AUC: 0.8291
# Cardiomegaly - AUC: 0.7179
# Nodule - AUC: 0.7697
# Mass - AUC: 0.7368
# Hernia - AUC: 0.8118
# Validation Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.15      0.92      0.26      1277
#      Consolidation       0.03      0.98      0.07       254
#       Infiltration       0.14      0.29      0.19       370
#       Pneumothorax       0.03      0.96      0.07       177
#              Edema       0.10      1.00      0.18      1244
#          Emphysema       0.01      1.00      0.03       149
#           Fibrosis       0.03      0.76      0.06       200
#           Effusion       0.33      0.46      0.39        28
#          Pneumonia       0.15      1.00      0.27      1929
# Pleural_Thickening       0.07      0.93      0.13       582
#       Cardiomegaly       0.06      0.98      0.11       666
#             Nodule       0.11      0.40      0.18       372
#               Mass       0.04      0.07      0.05       134
#             Hernia       0.03      1.00      0.05       350
#
#          micro avg       0.07      0.89      0.13      7732
#          macro avg       0.09      0.77      0.14      7732
#       weighted avg       0.11      0.89      0.18      7732
#        samples avg       0.07      0.37      0.11      7732
#
# Epoch 16/30 - Train Loss: 0.1385, Train Accuracy: 0.4828, Val Loss: 0.1359, Val Accuracy: 0.4926,
#
# Train Per-Class Accuracy:
#   Atelectasis: 0.9269
#   Consolidation: 0.9862
#   Infiltration: 0.2808
#   Pneumothorax: 0.9559
#   Edema: 1.0000
#   Emphysema: 0.9937
#   Fibrosis: 0.7821
#   Effusion: 0.5044
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9348
#   Cardiomegaly: 0.9876
#   Nodule: 0.4380
#   Mass: 0.1213
#   Hernia: 1.0000
#
# Validation Per-Class Accuracy:
#   Atelectasis: 0.9178
#   Consolidation: 0.9843
#   Infiltration: 0.2892
#   Pneumothorax: 0.9605
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.7550
#   Effusion: 0.4643
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9261
#   Cardiomegaly: 0.9775
#   Nodule: 0.3978
#   Mass: 0.0746
#   Hernia: 1.0000
#
# --------------------------------------------------
#
# Atelectasis - AUC: 0.7784
# Consolidation - AUC: 0.8948
# Infiltration - AUC: 0.8129
# Pneumothorax - AUC: 0.8992
# Edema - AUC: 0.8804
# Emphysema - AUC: 0.7779
# Fibrosis - AUC: 0.7649
# Effusion - AUC: 0.8825
# Pneumonia - AUC: 0.6836
# Pleural_Thickening - AUC: 0.8295
# Cardiomegaly - AUC: 0.7182
# Nodule - AUC: 0.7692
# Mass - AUC: 0.7394
# Hernia - AUC: 0.8130
# Validation Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.15      0.92      0.26      1277
#      Consolidation       0.04      0.98      0.07       254
#       Infiltration       0.15      0.31      0.20       370
#       Pneumothorax       0.03      0.97      0.06       177
#              Edema       0.10      1.00      0.18      1244
#          Emphysema       0.01      1.00      0.03       149
#           Fibrosis       0.03      0.77      0.06       200
#           Effusion       0.33      0.46      0.39        28
#          Pneumonia       0.15      1.00      0.27      1929
# Pleural_Thickening       0.07      0.93      0.13       582
#       Cardiomegaly       0.06      0.98      0.10       666
#             Nodule       0.11      0.42      0.18       372
#               Mass       0.04      0.09      0.06       134
#             Hernia       0.03      1.00      0.05       350
#
#          micro avg       0.07      0.89      0.13      7732
#          macro avg       0.09      0.77      0.14      7732
#       weighted avg       0.11      0.89      0.18      7732
#        samples avg       0.07      0.37      0.11      7732
#
# Epoch 17/30 - Train Loss: 0.1384, Train Accuracy: 0.4850, Val Loss: 0.1359, Val Accuracy: 0.4889,
#
# Train Per-Class Accuracy:
#   Atelectasis: 0.9293
#   Consolidation: 0.9842
#   Infiltration: 0.2965
#   Pneumothorax: 0.9484
#   Edema: 1.0000
#   Emphysema: 0.9929
#   Fibrosis: 0.7735
#   Effusion: 0.5044
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9337
#   Cardiomegaly: 0.9849
#   Nodule: 0.4251
#   Mass: 0.1065
#   Hernia: 1.0000
#
# Validation Per-Class Accuracy:
#   Atelectasis: 0.9209
#   Consolidation: 0.9803
#   Infiltration: 0.3054
#   Pneumothorax: 0.9661
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.7700
#   Effusion: 0.4643
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9313
#   Cardiomegaly: 0.9835
#   Nodule: 0.4167
#   Mass: 0.0896
#   Hernia: 1.0000
#
# --------------------------------------------------
#
# Atelectasis - AUC: 0.7793
# Consolidation - AUC: 0.8950
# Infiltration - AUC: 0.8135
# Pneumothorax - AUC: 0.8991
# Edema - AUC: 0.8809
# Emphysema - AUC: 0.7780
# Fibrosis - AUC: 0.7671
# Effusion - AUC: 0.8836
# Pneumonia - AUC: 0.6835
# Pleural_Thickening - AUC: 0.8291
# Cardiomegaly - AUC: 0.7180
# Nodule - AUC: 0.7688
# Mass - AUC: 0.7386
# Hernia - AUC: 0.8121
# Validation Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.15      0.92      0.26      1277
#      Consolidation       0.03      0.98      0.06       254
#       Infiltration       0.14      0.31      0.19       370
#       Pneumothorax       0.03      0.97      0.06       177
#              Edema       0.10      1.00      0.18      1244
#          Emphysema       0.01      1.00      0.03       149
#           Fibrosis       0.03      0.79      0.06       200
#           Effusion       0.32      0.46      0.38        28
#          Pneumonia       0.15      1.00      0.27      1929
# Pleural_Thickening       0.07      0.92      0.13       582
#       Cardiomegaly       0.06      0.97      0.11       666
#             Nodule       0.11      0.41      0.18       372
#               Mass       0.05      0.11      0.07       134
#             Hernia       0.03      1.00      0.05       350
#
#          micro avg       0.07      0.89      0.13      7732
#          macro avg       0.09      0.77      0.14      7732
#       weighted avg       0.11      0.89      0.18      7732
#        samples avg       0.06      0.37      0.11      7732
#
# Epoch 18/30 - Train Loss: 0.1383, Train Accuracy: 0.4845, Val Loss: 0.1357, Val Accuracy: 0.4900,
#
# Train Per-Class Accuracy:
#   Atelectasis: 0.9309
#   Consolidation: 0.9807
#   Infiltration: 0.2945
#   Pneumothorax: 0.9500
#   Edema: 1.0000
#   Emphysema: 0.9953
#   Fibrosis: 0.7716
#   Effusion: 0.5221
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9389
#   Cardiomegaly: 0.9849
#   Nodule: 0.4385
#   Mass: 0.1092
#   Hernia: 1.0000
#
# Validation Per-Class Accuracy:
#   Atelectasis: 0.9240
#   Consolidation: 0.9843
#   Infiltration: 0.3054
#   Pneumothorax: 0.9661
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.7850
#   Effusion: 0.4643
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9244
#   Cardiomegaly: 0.9715
#   Nodule: 0.4086
#   Mass: 0.1119
#   Hernia: 1.0000
#
# --------------------------------------------------
#
# Atelectasis - AUC: 0.7790
# Consolidation - AUC: 0.8958
# Infiltration - AUC: 0.8134
# Pneumothorax - AUC: 0.8988
# Edema - AUC: 0.8809
# Emphysema - AUC: 0.7784
# Fibrosis - AUC: 0.7666
# Effusion - AUC: 0.8902
# Pneumonia - AUC: 0.6842
# Pleural_Thickening - AUC: 0.8297
# Cardiomegaly - AUC: 0.7179
# Nodule - AUC: 0.7714
# Mass - AUC: 0.7375
# Hernia - AUC: 0.8129
# Validation Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.15      0.92      0.26      1277
#      Consolidation       0.03      0.98      0.07       254
#       Infiltration       0.14      0.30      0.19       370
#       Pneumothorax       0.04      0.95      0.07       177
#              Edema       0.10      1.00      0.18      1244
#          Emphysema       0.01      1.00      0.03       149
#           Fibrosis       0.03      0.81      0.06       200
#           Effusion       0.33      0.46      0.38        28
#          Pneumonia       0.15      1.00      0.27      1929
# Pleural_Thickening       0.07      0.93      0.13       582
#       Cardiomegaly       0.06      0.98      0.10       666
#             Nodule       0.11      0.44      0.18       372
#               Mass       0.04      0.12      0.07       134
#             Hernia       0.03      1.00      0.05       350
#
#          micro avg       0.07      0.90      0.13      7732
#          macro avg       0.09      0.78      0.14      7732
#       weighted avg       0.11      0.90      0.18      7732
#        samples avg       0.06      0.37      0.11      7732
#
# Epoch 19/30 - Train Loss: 0.1382, Train Accuracy: 0.4853, Val Loss: 0.1357, Val Accuracy: 0.4894,
#
# Train Per-Class Accuracy:
#   Atelectasis: 0.9279
#   Consolidation: 0.9821
#   Infiltration: 0.2905
#   Pneumothorax: 0.9509
#   Edema: 1.0000
#   Emphysema: 0.9929
#   Fibrosis: 0.7802
#   Effusion: 0.5133
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9337
#   Cardiomegaly: 0.9859
#   Nodule: 0.4337
#   Mass: 0.1213
#   Hernia: 1.0000
#
# Validation Per-Class Accuracy:
#   Atelectasis: 0.9193
#   Consolidation: 0.9843
#   Infiltration: 0.3027
#   Pneumothorax: 0.9548
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.8050
#   Effusion: 0.4643
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9261
#   Cardiomegaly: 0.9775
#   Nodule: 0.4435
#   Mass: 0.1194
#   Hernia: 1.0000
#
# --------------------------------------------------
#
# Atelectasis - AUC: 0.7786
# Consolidation - AUC: 0.8965
# Infiltration - AUC: 0.8134
# Pneumothorax - AUC: 0.8996
# Edema - AUC: 0.8813
# Emphysema - AUC: 0.7784
# Fibrosis - AUC: 0.7690
# Effusion - AUC: 0.8885
# Pneumonia - AUC: 0.6845
# Pleural_Thickening - AUC: 0.8293
# Cardiomegaly - AUC: 0.7185
# Nodule - AUC: 0.7717
# Mass - AUC: 0.7397
# Hernia - AUC: 0.8142
# Validation Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.15      0.90      0.26      1277
#      Consolidation       0.04      0.98      0.07       254
#       Infiltration       0.14      0.33      0.19       370
#       Pneumothorax       0.03      0.96      0.07       177
#              Edema       0.10      1.00      0.18      1244
#          Emphysema       0.01      1.00      0.03       149
#           Fibrosis       0.03      0.78      0.06       200
#           Effusion       0.29      0.46      0.36        28
#          Pneumonia       0.15      1.00      0.27      1929
# Pleural_Thickening       0.07      0.93      0.13       582
#       Cardiomegaly       0.06      0.99      0.11       666
#             Nodule       0.11      0.42      0.18       372
#               Mass       0.04      0.09      0.06       134
#             Hernia       0.03      1.00      0.05       350
#
#          micro avg       0.07      0.89      0.13      7732
#          macro avg       0.09      0.77      0.14      7732
#       weighted avg       0.11      0.89      0.19      7732
#        samples avg       0.07      0.37      0.11      7732
#
# Epoch 20/30 - Train Loss: 0.1381, Train Accuracy: 0.4862, Val Loss: 0.1356, Val Accuracy: 0.4956,
#
# Train Per-Class Accuracy:
#   Atelectasis: 0.9282
#   Consolidation: 0.9835
#   Infiltration: 0.2869
#   Pneumothorax: 0.9467
#   Edema: 1.0000
#   Emphysema: 0.9914
#   Fibrosis: 0.7888
#   Effusion: 0.5221
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9351
#   Cardiomegaly: 0.9839
#   Nodule: 0.4385
#   Mass: 0.1348
#   Hernia: 1.0000
#
# Validation Per-Class Accuracy:
#   Atelectasis: 0.9029
#   Consolidation: 0.9803
#   Infiltration: 0.3270
#   Pneumothorax: 0.9605
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.7800
#   Effusion: 0.4643
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9278
#   Cardiomegaly: 0.9880
#   Nodule: 0.4194
#   Mass: 0.0896
#   Hernia: 1.0000
#
# --------------------------------------------------
#
# Atelectasis - AUC: 0.7794
# Consolidation - AUC: 0.8950
# Infiltration - AUC: 0.8142
# Pneumothorax - AUC: 0.8987
# Edema - AUC: 0.8810
# Emphysema - AUC: 0.7802
# Fibrosis - AUC: 0.7718
# Effusion - AUC: 0.8858
# Pneumonia - AUC: 0.6845
# Pleural_Thickening - AUC: 0.8287
# Cardiomegaly - AUC: 0.7196
# Nodule - AUC: 0.7713
# Mass - AUC: 0.7410
# Hernia - AUC: 0.8140
# Validation Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.15      0.92      0.25      1277
#      Consolidation       0.04      0.98      0.07       254
#       Infiltration       0.13      0.33      0.19       370
#       Pneumothorax       0.03      0.96      0.07       177
#              Edema       0.10      1.00      0.18      1244
#          Emphysema       0.01      1.00      0.03       149
#           Fibrosis       0.03      0.82      0.06       200
#           Effusion       0.29      0.46      0.36        28
#          Pneumonia       0.15      1.00      0.27      1929
# Pleural_Thickening       0.06      0.94      0.12       582
#       Cardiomegaly       0.06      0.98      0.11       666
#             Nodule       0.11      0.42      0.17       372
#               Mass       0.05      0.10      0.07       134
#             Hernia       0.03      1.00      0.05       350
#
#          micro avg       0.07      0.90      0.13      7732
#          macro avg       0.09      0.78      0.14      7732
#       weighted avg       0.11      0.90      0.18      7732
#        samples avg       0.06      0.37      0.11      7732
#
# Epoch 21/30 - Train Loss: 0.1382, Train Accuracy: 0.4870, Val Loss: 0.1357, Val Accuracy: 0.4818,
#
# Train Per-Class Accuracy:
#   Atelectasis: 0.9246
#   Consolidation: 0.9835
#   Infiltration: 0.2913
#   Pneumothorax: 0.9442
#   Edema: 1.0000
#   Emphysema: 0.9929
#   Fibrosis: 0.7755
#   Effusion: 0.5133
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9354
#   Cardiomegaly: 0.9854
# ...
# Fibrosis - AUC: 0.7726
# Effusion - AUC: 0.8864
# Pneumonia - AUC: 0.6847
# Pleural_Thickening - AUC: 0.8290
# Cardiomegaly - AUC: 0.7195
# Nodule - AUC: 0.7736
# Mass - AUC: 0.7421
# Hernia - AUC: 0.8159
# Validation Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.15      0.92      0.26      1277
#      Consolidation       0.03      0.98      0.07       254
#       Infiltration       0.14      0.31      0.19       370
#       Pneumothorax       0.04      0.95      0.07       177
#              Edema       0.10      1.00      0.18      1244
#          Emphysema       0.01      1.00      0.03       149
#           Fibrosis       0.03      0.78      0.06       200
#           Effusion       0.31      0.46      0.37        28
#          Pneumonia       0.15      1.00      0.27      1929
# Pleural_Thickening       0.07      0.93      0.13       582
#       Cardiomegaly       0.06      0.99      0.10       666
#             Nodule       0.11      0.44      0.17       372
#               Mass       0.04      0.10      0.06       134
#             Hernia       0.03      1.00      0.05       350
#
#          micro avg       0.07      0.90      0.13      7732
#          macro avg       0.09      0.78      0.14      7732
#       weighted avg       0.11      0.90      0.18      7732
#        samples avg       0.07      0.37      0.11      7732
#
# Epoch 24/30 - Train Loss: 0.1379, Train Accuracy: 0.4874, Val Loss: 0.1355, Val Accuracy: 0.4922,
#
# Train Per-Class Accuracy:
#   Atelectasis: 0.9260
#   Consolidation: 0.9821
#   Infiltration: 0.2985
#   Pneumothorax: 0.9484
#   Edema: 1.0000
#   Emphysema: 0.9969
#   Fibrosis: 0.7888
#   Effusion: 0.5221
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9374
#   Cardiomegaly: 0.9842
#   Nodule: 0.4369
#   Mass: 0.1280
#   Hernia: 1.0000
#
# Validation Per-Class Accuracy:
#   Atelectasis: 0.9248
#   Consolidation: 0.9803
#   Infiltration: 0.3054
#   Pneumothorax: 0.9548
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.7750
#   Effusion: 0.4643
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9278
#   Cardiomegaly: 0.9865
#   Nodule: 0.4382
#   Mass: 0.1045
#   Hernia: 1.0000
#
# --------------------------------------------------
#
# Atelectasis - AUC: 0.7792
# Consolidation - AUC: 0.8962
# Infiltration - AUC: 0.8145
# Pneumothorax - AUC: 0.8991
# Edema - AUC: 0.8816
# Emphysema - AUC: 0.7804
# Fibrosis - AUC: 0.7718
# Effusion - AUC: 0.8916
# Pneumonia - AUC: 0.6854
# Pleural_Thickening - AUC: 0.8294
# Cardiomegaly - AUC: 0.7198
# Nodule - AUC: 0.7728
# Mass - AUC: 0.7416
# Hernia - AUC: 0.8158
# Validation Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.15      0.92      0.26      1277
#      Consolidation       0.03      0.98      0.07       254
#       Infiltration       0.14      0.32      0.20       370
#       Pneumothorax       0.03      0.96      0.07       177
#              Edema       0.10      1.00      0.18      1244
#          Emphysema       0.01      1.00      0.03       149
#           Fibrosis       0.03      0.79      0.06       200
#           Effusion       0.28      0.46      0.35        28
#          Pneumonia       0.15      1.00      0.27      1929
# Pleural_Thickening       0.07      0.93      0.13       582
#       Cardiomegaly       0.06      0.98      0.10       666
#             Nodule       0.11      0.41      0.18       372
#               Mass       0.04      0.09      0.06       134
#             Hernia       0.03      1.00      0.05       350
#
#          micro avg       0.07      0.89      0.13      7732
#          macro avg       0.09      0.77      0.14      7732
#       weighted avg       0.11      0.89      0.18      7732
#        samples avg       0.07      0.37      0.11      7732
#
# Epoch 25/30 - Train Loss: 0.1378, Train Accuracy: 0.4880, Val Loss: 0.1355, Val Accuracy: 0.4918,
#
# Train Per-Class Accuracy:
#   Atelectasis: 0.9265
#   Consolidation: 0.9862
#   Infiltration: 0.2917
#   Pneumothorax: 0.9492
#   Edema: 1.0000
#   Emphysema: 0.9961
#   Fibrosis: 0.7831
#   Effusion: 0.5221
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9366
#   Cardiomegaly: 0.9859
#   Nodule: 0.4353
#   Mass: 0.1280
#   Hernia: 1.0000
#
# Validation Per-Class Accuracy:
#   Atelectasis: 0.9225
#   Consolidation: 0.9803
#   Infiltration: 0.3243
#   Pneumothorax: 0.9605
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.7900
#   Effusion: 0.4643
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9296
#   Cardiomegaly: 0.9775
#   Nodule: 0.4086
#   Mass: 0.0896
#   Hernia: 1.0000
#
# --------------------------------------------------
#
# Atelectasis - AUC: 0.7803
# Consolidation - AUC: 0.8971
# Infiltration - AUC: 0.8146
# Pneumothorax - AUC: 0.8994
# Edema - AUC: 0.8813
# Emphysema - AUC: 0.7796
# Fibrosis - AUC: 0.7748
# Effusion - AUC: 0.8887
# Pneumonia - AUC: 0.6850
# Pleural_Thickening - AUC: 0.8301
# Cardiomegaly - AUC: 0.7209
# Nodule - AUC: 0.7744
# Mass - AUC: 0.7407
# Hernia - AUC: 0.8162
# Validation Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.15      0.92      0.26      1277
#      Consolidation       0.04      0.98      0.07       254
#       Infiltration       0.14      0.32      0.19       370
#       Pneumothorax       0.03      0.95      0.07       177
#              Edema       0.10      1.00      0.18      1244
#          Emphysema       0.01      1.00      0.03       149
#           Fibrosis       0.03      0.81      0.06       200
#           Effusion       0.28      0.46      0.35        28
#          Pneumonia       0.15      1.00      0.27      1929
# Pleural_Thickening       0.07      0.93      0.13       582
#       Cardiomegaly       0.06      0.99      0.10       666
#             Nodule       0.12      0.42      0.18       372
#               Mass       0.04      0.10      0.06       134
#             Hernia       0.03      1.00      0.05       350
#
#          micro avg       0.07      0.90      0.13      7732
#          macro avg       0.09      0.78      0.14      7732
#       weighted avg       0.11      0.90      0.18      7732
#        samples avg       0.06      0.37      0.11      7732
#
# Epoch 26/30 - Train Loss: 0.1378, Train Accuracy: 0.4902, Val Loss: 0.1354, Val Accuracy: 0.4892,
#
# Train Per-Class Accuracy:
#   Atelectasis: 0.9313
#   Consolidation: 0.9787
#   Infiltration: 0.2998
#   Pneumothorax: 0.9459
#   Edema: 1.0000
#   Emphysema: 0.9906
#   Fibrosis: 0.7764
#   Effusion: 0.5221
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9319
#   Cardiomegaly: 0.9819
#   Nodule: 0.4374
#   Mass: 0.1173
#   Hernia: 1.0000
#
# Validation Per-Class Accuracy:
#   Atelectasis: 0.9240
#   Consolidation: 0.9803
#   Infiltration: 0.3162
#   Pneumothorax: 0.9548
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.8150
#   Effusion: 0.4643
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9278
#   Cardiomegaly: 0.9880
#   Nodule: 0.4220
#   Mass: 0.1045
#   Hernia: 1.0000
#
# --------------------------------------------------
#
# Atelectasis - AUC: 0.7802
# Consolidation - AUC: 0.8961
# Infiltration - AUC: 0.8143
# Pneumothorax - AUC: 0.8985
# Edema - AUC: 0.8817
# Emphysema - AUC: 0.7805
# Fibrosis - AUC: 0.7740
# Effusion - AUC: 0.8848
# Pneumonia - AUC: 0.6853
# Pleural_Thickening - AUC: 0.8299
# Cardiomegaly - AUC: 0.7213
# Nodule - AUC: 0.7743
# Mass - AUC: 0.7407
# Hernia - AUC: 0.8162
# Validation Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.15      0.93      0.26      1277
#      Consolidation       0.03      0.98      0.07       254
#       Infiltration       0.13      0.32      0.19       370
#       Pneumothorax       0.03      0.96      0.07       177
#              Edema       0.10      1.00      0.18      1244
#          Emphysema       0.01      1.00      0.03       149
#           Fibrosis       0.03      0.77      0.06       200
#           Effusion       0.33      0.46      0.38        28
#          Pneumonia       0.15      1.00      0.27      1929
# Pleural_Thickening       0.07      0.93      0.13       582
#       Cardiomegaly       0.06      0.97      0.11       666
#             Nodule       0.11      0.44      0.18       372
#               Mass       0.04      0.10      0.06       134
#             Hernia       0.03      1.00      0.05       350
#
#          micro avg       0.07      0.90      0.13      7732
#          macro avg       0.09      0.78      0.14      7732
#       weighted avg       0.11      0.90      0.18      7732
#        samples avg       0.07      0.37      0.11      7732
#
# Epoch 27/30 - Train Loss: 0.1378, Train Accuracy: 0.4878, Val Loss: 0.1354, Val Accuracy: 0.4911,
#
# Train Per-Class Accuracy:
#   Atelectasis: 0.9285
#   Consolidation: 0.9828
#   Infiltration: 0.2973
#   Pneumothorax: 0.9467
#   Edema: 1.0000
#   Emphysema: 0.9937
#   Fibrosis: 0.7888
#   Effusion: 0.5221
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9313
#   Cardiomegaly: 0.9842
#   Nodule: 0.4390
#   Mass: 0.1375
#   Hernia: 1.0000
#
# Validation Per-Class Accuracy:
#   Atelectasis: 0.9264
#   Consolidation: 0.9843
#   Infiltration: 0.3216
#   Pneumothorax: 0.9605
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.7700
#   Effusion: 0.4643
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9296
#   Cardiomegaly: 0.9715
#   Nodule: 0.4435
#   Mass: 0.0970
#   Hernia: 1.0000
#
# --------------------------------------------------
#
# Atelectasis - AUC: 0.7803
# Consolidation - AUC: 0.8961
# Infiltration - AUC: 0.8145
# Pneumothorax - AUC: 0.8989
# Edema - AUC: 0.8813
# Emphysema - AUC: 0.7824
# Fibrosis - AUC: 0.7765
# Effusion - AUC: 0.8825
# Pneumonia - AUC: 0.6855
# Pleural_Thickening - AUC: 0.8302
# Cardiomegaly - AUC: 0.7216
# Nodule - AUC: 0.7740
# Mass - AUC: 0.7421
# Hernia - AUC: 0.8168
# Validation Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.15      0.93      0.26      1277
#      Consolidation       0.03      0.99      0.07       254
#       Infiltration       0.14      0.31      0.19       370
#       Pneumothorax       0.03      0.97      0.06       177
#              Edema       0.10      1.00      0.18      1244
#          Emphysema       0.01      1.00      0.03       149
#           Fibrosis       0.03      0.79      0.06       200
#           Effusion       0.32      0.46      0.38        28
#          Pneumonia       0.15      1.00      0.27      1929
# Pleural_Thickening       0.07      0.93      0.13       582
#       Cardiomegaly       0.06      0.98      0.11       666
#             Nodule       0.11      0.43      0.18       372
#               Mass       0.05      0.10      0.06       134
#             Hernia       0.03      1.00      0.05       350
#
#          micro avg       0.07      0.90      0.13      7732
#          macro avg       0.09      0.78      0.14      7732
#       weighted avg       0.11      0.90      0.18      7732
#        samples avg       0.07      0.37      0.11      7732
#
# Epoch 28/30 - Train Loss: 0.1377, Train Accuracy: 0.4895, Val Loss: 0.1355, Val Accuracy: 0.4873,
#
# Train Per-Class Accuracy:
#   Atelectasis: 0.9269
#   Consolidation: 0.9800
#   Infiltration: 0.2953
#   Pneumothorax: 0.9525
#   Edema: 1.0000
#   Emphysema: 0.9961
#   Fibrosis: 0.7916
#   Effusion: 0.5398
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9380
#   Cardiomegaly: 0.9829
#   Nodule: 0.4380
#   Mass: 0.1253
#   Hernia: 1.0000
#
# Validation Per-Class Accuracy:
#   Atelectasis: 0.9264
#   Consolidation: 0.9882
#   Infiltration: 0.3135
#   Pneumothorax: 0.9661
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.7850
#   Effusion: 0.4643
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9278
#   Cardiomegaly: 0.9790
#   Nodule: 0.4301
#   Mass: 0.0970
#   Hernia: 1.0000
#
# --------------------------------------------------
#
# Atelectasis - AUC: 0.7804
# Consolidation - AUC: 0.8979
# Infiltration - AUC: 0.8142
# Pneumothorax - AUC: 0.8992
# Edema - AUC: 0.8817
# Emphysema - AUC: 0.7794
# Fibrosis - AUC: 0.7741
# Effusion - AUC: 0.8896
# Pneumonia - AUC: 0.6852
# Pleural_Thickening - AUC: 0.8299
# Cardiomegaly - AUC: 0.7207
# Nodule - AUC: 0.7754
# Mass - AUC: 0.7417
# Hernia - AUC: 0.8165
# Validation Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.15      0.91      0.26      1277
#      Consolidation       0.04      0.98      0.07       254
#       Infiltration       0.15      0.29      0.20       370
#       Pneumothorax       0.04      0.95      0.07       177
#              Edema       0.10      1.00      0.18      1244
#          Emphysema       0.01      1.00      0.03       149
#           Fibrosis       0.03      0.76      0.06       200
#           Effusion       0.34      0.46      0.39        28
#          Pneumonia       0.15      1.00      0.27      1929
# Pleural_Thickening       0.08      0.92      0.14       582
#       Cardiomegaly       0.06      0.97      0.11       666
#             Nodule       0.11      0.45      0.18       372
#               Mass       0.04      0.13      0.06       134
#             Hernia       0.03      1.00      0.05       350
#
#          micro avg       0.07      0.89      0.14      7732
#          macro avg       0.10      0.77      0.15      7732
#       weighted avg       0.11      0.89      0.19      7732
#        samples avg       0.07      0.37      0.11      7732
#
# Epoch 29/30 - Train Loss: 0.1377, Train Accuracy: 0.4892, Val Loss: 0.1353, Val Accuracy: 0.5076,
#
# Train Per-Class Accuracy:
#   Atelectasis: 0.9279
#   Consolidation: 0.9828
#   Infiltration: 0.3034
#   Pneumothorax: 0.9500
#   Edema: 1.0000
#   Emphysema: 0.9929
#   Fibrosis: 0.7907
#   Effusion: 0.5221
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9366
#   Cardiomegaly: 0.9827
#   Nodule: 0.4283
#   Mass: 0.1334
#   Hernia: 1.0000
#
# Validation Per-Class Accuracy:
#   Atelectasis: 0.9076
#   Consolidation: 0.9803
#   Infiltration: 0.2919
#   Pneumothorax: 0.9548
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.7550
#   Effusion: 0.4643
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9158
#   Cardiomegaly: 0.9730
#   Nodule: 0.4516
#   Mass: 0.1343
#   Hernia: 1.0000
#
# --------------------------------------------------
#
# Atelectasis - AUC: 0.7802
# Consolidation - AUC: 0.8974
# Infiltration - AUC: 0.8146
# Pneumothorax - AUC: 0.8987
# Edema - AUC: 0.8815
# Emphysema - AUC: 0.7813
# Fibrosis - AUC: 0.7759
# Effusion - AUC: 0.8879
# Pneumonia - AUC: 0.6855
# Pleural_Thickening - AUC: 0.8296
# Cardiomegaly - AUC: 0.7226
# Nodule - AUC: 0.7757
# Mass - AUC: 0.7435
# Hernia - AUC: 0.8175
# Validation Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.15      0.92      0.25      1277
#      Consolidation       0.04      0.98      0.07       254
#       Infiltration       0.14      0.35      0.20       370
#       Pneumothorax       0.04      0.95      0.07       177
#              Edema       0.10      1.00      0.18      1244
#          Emphysema       0.01      1.00      0.03       149
#           Fibrosis       0.03      0.78      0.06       200
#           Effusion       0.29      0.46      0.36        28
#          Pneumonia       0.15      1.00      0.27      1929
# Pleural_Thickening       0.07      0.93      0.13       582
#       Cardiomegaly       0.06      0.97      0.11       666
#             Nodule       0.12      0.42      0.18       372
#               Mass       0.04      0.10      0.06       134
#             Hernia       0.03      1.00      0.05       350
#
#          micro avg       0.07      0.90      0.14      7732
#          macro avg       0.09      0.78      0.14      7732
#       weighted avg       0.11      0.90      0.19      7732
#        samples avg       0.07      0.37      0.11      7732
#
# Epoch 30/30 - Train Loss: 0.1376, Train Accuracy: 0.4901, Val Loss: 0.1354, Val Accuracy: 0.4973,
#
# Train Per-Class Accuracy:
#   Atelectasis: 0.9270
#   Consolidation: 0.9842
#   Infiltration: 0.2869
#   Pneumothorax: 0.9459
#   Edema: 1.0000
#   Emphysema: 0.9937
#   Fibrosis: 0.7916
#   Effusion: 0.5221
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9340
#   Cardiomegaly: 0.9834
#   Nodule: 0.4401
#   Mass: 0.1415
#   Hernia: 1.0000
#
# Validation Per-Class Accuracy:
#   Atelectasis: 0.9248
#   Consolidation: 0.9803
#   Infiltration: 0.3514
#   Pneumothorax: 0.9548
#   Edema: 1.0000
#   Emphysema: 1.0000
#   Fibrosis: 0.7750
#   Effusion: 0.4643
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9296
#   Cardiomegaly: 0.9700
#   Nodule: 0.4220
#   Mass: 0.1045
#   Hernia: 1.0000
#
# --------------------------------------------------

# %%
# Testing the trained model
model.eval()

test_loss = 0
correct = 0
total = 0
test_preds = []
test_probs = []
test_labels = []
test_correct_per_class = [0] * len(class_names)
test_total_per_class = [0] * len(class_names)

with torch.no_grad():
    for batch in test_loader:  
        images = batch["img"].to(device)
        labels = batch["lab"].to(device)

        outputs = model(images)
        probabilities = torch.sigmoid(outputs)
        loss = criterion(outputs, labels.float())
        test_loss += loss.item()

        preds = (probabilities > thresholds).float()
        correct += (preds == labels).sum().item()
        total += labels.numel()

        test_preds.append(preds.cpu())
        test_probs.append(probabilities.cpu())
        test_labels.append(labels.cpu())

        for i in range(len(class_names)):
            test_correct_per_class[i] += ((preds[:, i] == labels[:, i]) & (labels[:, i] == 1)).sum().item()
            test_total_per_class[i] += (labels[:, i] == 1).sum().item()

test_preds = torch.cat(test_preds).numpy()
test_probs = torch.cat(test_probs).numpy()
test_labels = torch.cat(test_labels).numpy()

test_accuracy = correct / total
test_loss = test_loss / len(test_loader)

test_class_accuracies = [
    correct / total if total > 0 else 0
    for correct, total in zip(test_correct_per_class, test_total_per_class)
]

for i, class_name in enumerate(class_names):
    auc_score = roc_auc_score(test_labels[:, i], test_probs[:, i])
    print(f"{class_name} - AUC: {auc_score:.4f}")

test_class_report = classification_report(
    test_labels, test_preds, target_names=class_names, zero_division=0)
print("\nTest Classification Report:\n", test_class_report)

print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")

print("\nTest Per-Class Accuracy:")
for i, class_name in enumerate(class_names):
    print(f"  {class_name}: {test_class_accuracies[i]:.4f}")
# Out:
# Atelectasis - AUC: 0.7313
# Consolidation - AUC: 0.8649
# Infiltration - AUC: 0.7208
# Pneumothorax - AUC: 0.8108
# Edema - AUC: 0.7911
# Emphysema - AUC: 0.7493
# Fibrosis - AUC: 0.7734
# Effusion - AUC: 0.8911
# Pneumonia - AUC: 0.6825
# Pleural_Thickening - AUC: 0.7772
# Cardiomegaly - AUC: 0.7022
# Nodule - AUC: 0.7246
# Mass - AUC: 0.6831
# Hernia - AUC: 0.7890
#
# Test Classification Report:
#                      precision    recall  f1-score   support
#
#        Atelectasis       0.15      0.97      0.26      3279
#      Consolidation       0.06      0.98      0.11      1069
#       Infiltration       0.15      0.45      0.22      1815
#       Pneumothorax       0.05      0.97      0.10       925
#              Edema       0.18      1.00      0.31      4658
#          Emphysema       0.05      1.00      0.09      1093
#           Fibrosis       0.04      0.76      0.07       435
#           Effusion       0.35      0.56      0.43        86
#          Pneumonia       0.24      1.00      0.39      6112
# Pleural_Thickening       0.08      0.97      0.15      1748
#       Cardiomegaly       0.07      0.99      0.13      1623
#             Nodule       0.10      0.50      0.17      1143
#               Mass       0.06      0.23      0.09       555
#             Hernia       0.10      1.00      0.19      2665
#
#          micro avg       0.11      0.91      0.20     27206
#          macro avg       0.12      0.81      0.19     27206
#       weighted avg       0.15      0.91      0.24     27206
#        samples avg       0.10      0.56      0.17     27206
#
# Test Loss: 0.2150, Test Accuracy: 0.4331
#
# Test Per-Class Accuracy:
#   Atelectasis: 0.9658
#   Consolidation: 0.9766
#   Infiltration: 0.4479
#   Pneumothorax: 0.9676
#   Edema: 1.0000
#   Emphysema: 0.9954
#   Fibrosis: 0.7563
#   Effusion: 0.5581
#   Pneumonia: 1.0000
#   Pleural_Thickening: 0.9691
#   Cardiomegaly: 0.9901
#   Nodule: 0.4961
#   Mass: 0.2270
#   Hernia: 1.0000

# %%
palette = sns.color_palette("hls", 4)

# Plot Loss
sns.set(style="whitegrid")
plt.figure(figsize=(10, 8))
sns.lineplot(x=range(num_epochs), y=train_losses, label='Train', color=palette[2])
sns.lineplot(x=range(num_epochs), y=val_losses, label='Validation', color=palette[3])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.tight_layout()
plt.savefig('loss_densenet121.png')
plt.show()

# Plot Accuracy
sns.set(style="whitegrid")
plt.figure(figsize=(10, 8))
sns.lineplot(x=range(num_epochs), y=train_accuracies, label='Train', color=palette[2])
sns.lineplot(x=range(num_epochs), y=val_accuracies, label='Validation', color=palette[3])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.tight_layout()
plt.savefig('accuracy_desenet121.png')
plt.show()

# %%
# Plot AUROC
palette = sns.color_palette("hls", len(class_names))
plt.figure(figsize=(10, 10))

for i, (class_name, color) in enumerate(zip(class_names, palette)):
    fpr, tpr, _ = roc_curve(test_labels[:, i], test_probs[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, color=color, label=f"{class_name} (AUC: {roc_auc:.2f})")
    
plt.plot([0, 1], [0, 1], 'k--', lw=2)

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc="lower right")
plt.grid()
plt.tight_layout()
plt.savefig('auc_densenet121.png')
plt.show()
